# %% [markdown]
# <a href="https://colab.research.google.com/github/man-swi/Vrtual-try-on/blob/main/Virtual_Try_On_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# !unzip "/content/drive/MyDrive/virtual-try-on-outfit-change.zip" -d /content/

import os
os.chdir('/content/virtual-try-on-outfit-change')
# !ls
import sys
current_project_path = os.getcwd()
if current_project_path not in sys.path:
    sys.path.append(current_project_path)
    print(f"Added {current_project_path} to sys.path")
# Out:
# Mounted at /content/drive
# Archive:  /content/drive/MyDrive/virtual-try-on-outfit-change.zip
#    creating: /content/virtual-try-on-outfit-change/.git/
#   inflating: /content/virtual-try-on-outfit-change/.git/config
#   inflating: /content/virtual-try-on-outfit-change/.git/description
#   inflating: /content/virtual-try-on-outfit-change/.git/FETCH_HEAD
#  extracting: /content/virtual-try-on-outfit-change/.git/HEAD
#    creating: /content/virtual-try-on-outfit-change/.git/hooks/
#   inflating: /content/virtual-try-on-outfit-change/.git/hooks/applypatch-msg.sample
#   inflating: /content/virtual-try-on-outfit-change/.git/hooks/commit-msg.sample
#   inflating: /content/virtual-try-on-outfit-change/.git/hooks/fsmonitor-watchman.sample
#   inflating: /content/virtual-try-on-outfit-change/.git/hooks/post-update.sample
#   inflating: /content/virtual-try-on-outfit-change/.git/hooks/pre-applypatch.sample
#   inflating: /content/virtual-try-on-outfit-change/.git/hooks/pre-commit.sample
#   inflating: /content/virtual-try-on-outfit-change/.git/hooks/pre-merge-commit.sample
#   inflating: /content/virtual-try-on-outfit-change/.git/hooks/prepare-commit-msg.sample
#   inflating: /content/virtual-try-on-outfit-change/.git/hooks/pre-push.sample
#   inflating: /content/virtual-try-on-outfit-change/.git/hooks/pre-rebase.sample
#   inflating: /content/virtual-try-on-outfit-change/.git/hooks/pre-receive.sample
#   inflating: /content/virtual-try-on-outfit-change/.git/hooks/push-to-checkout.sample
#   inflating: /content/virtual-try-on-outfit-change/.git/hooks/sendemail-validate.sample
#   inflating: /content/virtual-try-on-outfit-change/.git/hooks/update.sample
#   inflating: /content/virtual-try-on-outfit-change/.git/index
#    creating: /content/virtual-try-on-outfit-change/.git/info/
#   inflating: /content/virtual-try-on-outfit-change/.git/info/exclude
#    creating: /content/virtual-try-on-outfit-change/.git/logs/
#   inflating: /content/virtual-try-on-outfit-change/.git/logs/HEAD
#    creating: /content/virtual-try-on-outfit-change/.git/logs/refs/
#    creating: /content/virtual-try-on-outfit-change/.git/logs/refs/heads/
#   inflating: /content/virtual-try-on-outfit-change/.git/logs/refs/heads/main
#    creating: /content/virtual-try-on-outfit-change/.git/logs/refs/remotes/
#    creating: /content/virtual-try-on-outfit-change/.git/logs/refs/remotes/origin/
#   inflating: /content/virtual-try-on-outfit-change/.git/logs/refs/remotes/origin/HEAD
#    creating: /content/virtual-try-on-outfit-change/.git/objects/
#    creating: /content/virtual-try-on-outfit-change/.git/objects/info/
#    creating: /content/virtual-try-on-outfit-change/.git/objects/pack/
#   inflating: /content/virtual-try-on-outfit-change/.git/objects/pack/pack-bebfee2ec4aaf5e97125f5bc640fec909d97bae9.idx
#   inflating: /content/virtual-try-on-outfit-change/.git/objects/pack/pack-bebfee2ec4aaf5e97125f5bc640fec909d97bae9.pack
#   inflating: /content/virtual-try-on-outfit-change/.git/objects/pack/pack-bebfee2ec4aaf5e97125f5bc640fec909d97bae9.rev
#   inflating: /content/virtual-try-on-outfit-change/.git/packed-refs
#    creating: /content/virtual-try-on-outfit-change/.git/refs/
#    creating: /content/virtual-try-on-outfit-change/.git/refs/heads/
#  extracting: /content/virtual-try-on-outfit-change/.git/refs/heads/main
#    creating: /content/virtual-try-on-outfit-change/.git/refs/remotes/
#    creating: /content/virtual-try-on-outfit-change/.git/refs/remotes/origin/
#  extracting: /content/virtual-try-on-outfit-change/.git/refs/remotes/origin/HEAD
#    creating: /content/virtual-try-on-outfit-change/.git/refs/tags/
#   inflating: /content/virtual-try-on-outfit-change/app.py
#    creating: /content/virtual-try-on-outfit-change/images/
#   inflating: /content/virtual-try-on-outfit-change/images/Results.png
#   inflating: /content/virtual-try-on-outfit-change/LICENSE
#    creating: /content/virtual-try-on-outfit-change/notebook/
#   inflating: /content/virtual-try-on-outfit-change/notebook/data_preparation.ipynb
#   inflating: /content/virtual-try-on-outfit-change/notebook/model_evaluation.ipynb
#   inflating: /content/virtual-try-on-outfit-change/notebook/model_training.ipynb
#   inflating: /content/virtual-try-on-outfit-change/README.md
#   inflating: /content/virtual-try-on-outfit-change/requirements.txt
#   inflating: /content/virtual-try-on-outfit-change/setup.py
#   inflating: /content/virtual-try-on-outfit-change/try.png
#    creating: /content/virtual-try-on-outfit-change/venv/
#    creating: /content/virtual-try-on-outfit-change/venv/Include/
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/_distutils_hack/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/_distutils_hack/__init__.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/_distutils_hack/__pycache__/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/_distutils_hack/__pycache__/__init__.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/_distutils_hack/__pycache__/override.cpython-311.pyc
#  extracting: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/_distutils_hack/override.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/distutils-precedence.pth
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/__init__.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/__main__.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/__pip-runner__.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/__pycache__/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/__pycache__/__init__.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/__pycache__/__main__.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/__pycache__/__pip-runner__.cpython-311.pyc
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/__init__.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/__pycache__/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/__pycache__/__init__.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/__pycache__/build_env.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/__pycache__/cache.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/__pycache__/configuration.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/__pycache__/exceptions.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/__pycache__/main.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/__pycache__/pyproject.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/__pycache__/self_outdated_check.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/__pycache__/wheel_builder.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/build_env.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/cache.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/cli/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/cli/__init__.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/cli/__pycache__/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/cli/__pycache__/__init__.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/cli/__pycache__/autocompletion.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/cli/__pycache__/base_command.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/cli/__pycache__/cmdoptions.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/cli/__pycache__/command_context.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/cli/__pycache__/index_command.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/cli/__pycache__/main.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/cli/__pycache__/main_parser.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/cli/__pycache__/parser.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/cli/__pycache__/progress_bars.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/cli/__pycache__/req_command.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/cli/__pycache__/spinners.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/cli/__pycache__/status_codes.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/cli/autocompletion.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/cli/base_command.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/cli/cmdoptions.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/cli/command_context.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/cli/index_command.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/cli/main.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/cli/main_parser.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/cli/parser.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/cli/progress_bars.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/cli/req_command.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/cli/spinners.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/cli/status_codes.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/__init__.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/__pycache__/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/__pycache__/__init__.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/__pycache__/cache.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/__pycache__/check.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/__pycache__/completion.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/__pycache__/configuration.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/__pycache__/debug.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/__pycache__/download.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/__pycache__/freeze.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/__pycache__/hash.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/__pycache__/help.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/__pycache__/index.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/__pycache__/inspect.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/__pycache__/install.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/__pycache__/list.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/__pycache__/lock.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/__pycache__/search.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/__pycache__/show.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/__pycache__/uninstall.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/__pycache__/wheel.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/cache.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/check.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/completion.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/configuration.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/debug.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/download.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/freeze.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/hash.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/help.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/index.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/inspect.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/install.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/list.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/lock.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/search.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/show.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/uninstall.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/commands/wheel.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/configuration.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/distributions/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/distributions/__init__.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/distributions/__pycache__/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/distributions/__pycache__/__init__.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/distributions/__pycache__/base.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/distributions/__pycache__/installed.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/distributions/__pycache__/sdist.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/distributions/__pycache__/wheel.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/distributions/base.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/distributions/installed.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/distributions/sdist.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/distributions/wheel.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/exceptions.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/index/
#  extracting: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/index/__init__.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/index/__pycache__/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/index/__pycache__/__init__.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/index/__pycache__/collector.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/index/__pycache__/package_finder.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/index/__pycache__/sources.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/index/collector.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/index/package_finder.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/index/sources.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/locations/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/locations/__init__.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/locations/__pycache__/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/locations/__pycache__/__init__.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/locations/__pycache__/_distutils.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/locations/__pycache__/_sysconfig.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/locations/__pycache__/base.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/locations/_distutils.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/locations/_sysconfig.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/locations/base.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/main.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/metadata/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/metadata/__init__.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/metadata/__pycache__/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/metadata/__pycache__/__init__.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/metadata/__pycache__/_json.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/metadata/__pycache__/base.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/metadata/__pycache__/pkg_resources.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/metadata/_json.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/metadata/base.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/metadata/importlib/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/metadata/importlib/__init__.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/metadata/importlib/__pycache__/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/metadata/importlib/__pycache__/__init__.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/metadata/importlib/__pycache__/_compat.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/metadata/importlib/__pycache__/_dists.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/metadata/importlib/__pycache__/_envs.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/metadata/importlib/_compat.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/metadata/importlib/_dists.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/metadata/importlib/_envs.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/metadata/pkg_resources.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/models/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/models/__init__.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/models/__pycache__/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/models/__pycache__/__init__.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/models/__pycache__/candidate.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/models/__pycache__/direct_url.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/models/__pycache__/format_control.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/models/__pycache__/index.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/models/__pycache__/installation_report.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/models/__pycache__/link.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/models/__pycache__/pylock.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/models/__pycache__/scheme.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/models/__pycache__/search_scope.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/models/__pycache__/selection_prefs.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/models/__pycache__/target_python.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/models/__pycache__/wheel.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/models/candidate.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/models/direct_url.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/models/format_control.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/models/index.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/models/installation_report.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/models/link.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/models/pylock.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/models/scheme.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/models/search_scope.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/models/selection_prefs.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/models/target_python.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/models/wheel.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/network/
#  extracting: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/network/__init__.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/network/__pycache__/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/network/__pycache__/__init__.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/network/__pycache__/auth.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/network/__pycache__/cache.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/network/__pycache__/download.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/network/__pycache__/lazy_wheel.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/network/__pycache__/session.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/network/__pycache__/utils.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/network/__pycache__/xmlrpc.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/network/auth.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/network/cache.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/network/download.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/network/lazy_wheel.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/network/session.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/network/utils.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/network/xmlrpc.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/operations/
#  extracting: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/operations/__init__.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/operations/__pycache__/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/operations/__pycache__/__init__.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/operations/__pycache__/check.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/operations/__pycache__/freeze.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/operations/__pycache__/prepare.cpython-311.pyc
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/operations/build/
#  extracting: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/operations/build/__init__.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/operations/build/__pycache__/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/operations/build/__pycache__/__init__.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/operations/build/__pycache__/build_tracker.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/operations/build/__pycache__/metadata.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/operations/build/__pycache__/metadata_editable.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/operations/build/__pycache__/metadata_legacy.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/operations/build/__pycache__/wheel.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/operations/build/__pycache__/wheel_editable.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/operations/build/__pycache__/wheel_legacy.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/operations/build/build_tracker.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/operations/build/metadata.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/operations/build/metadata_editable.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/operations/build/metadata_legacy.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/operations/build/wheel.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/operations/build/wheel_editable.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/operations/build/wheel_legacy.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/operations/check.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/operations/freeze.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/operations/install/
#  extracting: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/operations/install/__init__.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/operations/install/__pycache__/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/operations/install/__pycache__/__init__.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/operations/install/__pycache__/editable_legacy.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/operations/install/__pycache__/wheel.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/operations/install/editable_legacy.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/operations/install/wheel.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/operations/prepare.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/pyproject.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/req/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/req/__init__.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/req/__pycache__/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/req/__pycache__/__init__.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/req/__pycache__/constructors.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/req/__pycache__/req_dependency_group.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/req/__pycache__/req_file.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/req/__pycache__/req_install.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/req/__pycache__/req_set.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/req/__pycache__/req_uninstall.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/req/constructors.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/req/req_dependency_group.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/req/req_file.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/req/req_install.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/req/req_set.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/req/req_uninstall.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/resolution/
#  extracting: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/resolution/__init__.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/resolution/__pycache__/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/resolution/__pycache__/__init__.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/resolution/__pycache__/base.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/resolution/base.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/resolution/legacy/
#  extracting: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/resolution/legacy/__init__.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/resolution/legacy/__pycache__/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/resolution/legacy/__pycache__/__init__.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/resolution/legacy/__pycache__/resolver.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/resolution/legacy/resolver.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/resolution/resolvelib/
#  extracting: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/resolution/resolvelib/__init__.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/resolution/resolvelib/__pycache__/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/resolution/resolvelib/__pycache__/__init__.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/resolution/resolvelib/__pycache__/base.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/resolution/resolvelib/__pycache__/candidates.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/resolution/resolvelib/__pycache__/factory.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/resolution/resolvelib/__pycache__/found_candidates.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/resolution/resolvelib/__pycache__/provider.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/resolution/resolvelib/__pycache__/reporter.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/resolution/resolvelib/__pycache__/requirements.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/resolution/resolvelib/__pycache__/resolver.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/resolution/resolvelib/base.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/resolution/resolvelib/candidates.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/resolution/resolvelib/factory.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/resolution/resolvelib/found_candidates.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/resolution/resolvelib/provider.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/resolution/resolvelib/reporter.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/resolution/resolvelib/requirements.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/resolution/resolvelib/resolver.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/self_outdated_check.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/
#  extracting: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/__init__.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/__pycache__/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/__pycache__/__init__.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/__pycache__/_jaraco_text.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/__pycache__/_log.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/__pycache__/appdirs.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/__pycache__/compat.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/__pycache__/compatibility_tags.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/__pycache__/datetime.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/__pycache__/deprecation.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/__pycache__/direct_url_helpers.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/__pycache__/egg_link.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/__pycache__/entrypoints.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/__pycache__/filesystem.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/__pycache__/filetypes.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/__pycache__/glibc.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/__pycache__/hashes.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/__pycache__/logging.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/__pycache__/misc.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/__pycache__/packaging.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/__pycache__/retry.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/__pycache__/setuptools_build.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/__pycache__/subprocess.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/__pycache__/temp_dir.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/__pycache__/unpacking.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/__pycache__/urls.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/__pycache__/virtualenv.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/__pycache__/wheel.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/_jaraco_text.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/_log.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/appdirs.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/compat.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/compatibility_tags.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/datetime.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/deprecation.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/direct_url_helpers.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/egg_link.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/entrypoints.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/filesystem.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/filetypes.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/glibc.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/hashes.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/logging.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/misc.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/packaging.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/retry.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/setuptools_build.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/subprocess.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/temp_dir.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/unpacking.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/urls.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/virtualenv.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/utils/wheel.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/vcs/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/vcs/__init__.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/vcs/__pycache__/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/vcs/__pycache__/__init__.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/vcs/__pycache__/bazaar.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/vcs/__pycache__/git.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/vcs/__pycache__/mercurial.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/vcs/__pycache__/subversion.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/vcs/__pycache__/versioncontrol.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/vcs/bazaar.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/vcs/git.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/vcs/mercurial.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/vcs/subversion.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/vcs/versioncontrol.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_internal/wheel_builder.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_vendor/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_vendor/__init__.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_vendor/__pycache__/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_vendor/__pycache__/__init__.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/pip/_vendor/__pycache__/typing_extensions.cpython-311.pyc
# ...
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/__pycache__/build_ext.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/__pycache__/build_py.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/__pycache__/develop.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/__pycache__/dist_info.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/__pycache__/easy_install.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/__pycache__/editable_wheel.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/__pycache__/egg_info.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/__pycache__/install.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/__pycache__/install_egg_info.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/__pycache__/install_lib.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/__pycache__/install_scripts.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/__pycache__/py36compat.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/__pycache__/register.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/__pycache__/rotate.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/__pycache__/saveopts.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/__pycache__/sdist.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/__pycache__/setopt.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/__pycache__/test.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/__pycache__/upload.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/__pycache__/upload_docs.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/alias.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/bdist_egg.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/bdist_rpm.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/build.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/build_clib.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/build_ext.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/build_py.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/develop.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/dist_info.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/easy_install.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/editable_wheel.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/egg_info.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/install.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/install_egg_info.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/install_lib.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/install_scripts.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/launcher manifest.xml
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/py36compat.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/register.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/rotate.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/saveopts.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/sdist.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/setopt.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/test.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/upload.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/command/upload_docs.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/config/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/config/__init__.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/config/__pycache__/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/config/__pycache__/__init__.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/config/__pycache__/_apply_pyprojecttoml.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/config/__pycache__/expand.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/config/__pycache__/pyprojecttoml.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/config/__pycache__/setupcfg.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/config/_apply_pyprojecttoml.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/config/_validate_pyproject/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/config/_validate_pyproject/__init__.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/config/_validate_pyproject/__pycache__/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/config/_validate_pyproject/__pycache__/__init__.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/config/_validate_pyproject/__pycache__/error_reporting.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/config/_validate_pyproject/__pycache__/extra_validations.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/config/_validate_pyproject/__pycache__/fastjsonschema_exceptions.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/config/_validate_pyproject/__pycache__/fastjsonschema_validations.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/config/_validate_pyproject/__pycache__/formats.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/config/_validate_pyproject/error_reporting.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/config/_validate_pyproject/extra_validations.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/config/_validate_pyproject/fastjsonschema_exceptions.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/config/_validate_pyproject/fastjsonschema_validations.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/config/_validate_pyproject/formats.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/config/expand.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/config/pyprojecttoml.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/config/setupcfg.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/dep_util.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/depends.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/discovery.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/dist.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/errors.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/extension.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/extern/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/extern/__init__.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/extern/__pycache__/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/extern/__pycache__/__init__.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/glob.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/gui.exe
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/gui-32.exe
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/gui-64.exe
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/gui-arm64.exe
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/installer.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/launch.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/logging.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/monkey.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/msvc.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/namespaces.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/package_index.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/py34compat.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/sandbox.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/script (dev).tmpl
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/script.tmpl
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/unicode_utils.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/version.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/wheel.py
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools/windows_support.py
#    creating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools-65.5.0.dist-info/
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools-65.5.0.dist-info/entry_points.txt
#  extracting: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools-65.5.0.dist-info/INSTALLER
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools-65.5.0.dist-info/LICENSE
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools-65.5.0.dist-info/METADATA
#   inflating: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools-65.5.0.dist-info/RECORD
#  extracting: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools-65.5.0.dist-info/REQUESTED
#  extracting: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools-65.5.0.dist-info/top_level.txt
#  extracting: /content/virtual-try-on-outfit-change/venv/Lib/site-packages/setuptools-65.5.0.dist-info/WHEEL
#   inflating: /content/virtual-try-on-outfit-change/venv/pyvenv.cfg
#    creating: /content/virtual-try-on-outfit-change/venv/Scripts/
#   inflating: /content/virtual-try-on-outfit-change/venv/Scripts/activate
#   inflating: /content/virtual-try-on-outfit-change/venv/Scripts/activate.bat
#   inflating: /content/virtual-try-on-outfit-change/venv/Scripts/Activate.ps1
#   inflating: /content/virtual-try-on-outfit-change/venv/Scripts/deactivate.bat
#   inflating: /content/virtual-try-on-outfit-change/venv/Scripts/pip.exe
#   inflating: /content/virtual-try-on-outfit-change/venv/Scripts/pip3.11.exe
#   inflating: /content/virtual-try-on-outfit-change/venv/Scripts/pip3.exe
#   inflating: /content/virtual-try-on-outfit-change/venv/Scripts/python.exe
#   inflating: /content/virtual-try-on-outfit-change/venv/Scripts/python_d.exe
#   inflating: /content/virtual-try-on-outfit-change/venv/Scripts/pythonw.exe
#   inflating: /content/virtual-try-on-outfit-change/venv/Scripts/pythonw_d.exe
#    creating: /content/virtual-try-on-outfit-change/virtual_try_on/
#  extracting: /content/virtual-try-on-outfit-change/virtual_try_on/__init__.py
#    creating: /content/virtual-try-on-outfit-change/virtual_try_on/__pycache__/
#   inflating: /content/virtual-try-on-outfit-change/virtual_try_on/__pycache__/__init__.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/virtual_try_on/__pycache__/body_segmentation.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/virtual_try_on/__pycache__/clothes_segmentation.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/virtual_try_on/__pycache__/try_on.cpython-311.pyc
#   inflating: /content/virtual-try-on-outfit-change/virtual_try_on/body_segmentation.py
#   inflating: /content/virtual-try-on-outfit-change/virtual_try_on/clothes_segmentation.py
#   inflating: /content/virtual-try-on-outfit-change/virtual_try_on/data.py
#   inflating: /content/virtual-try-on-outfit-change/virtual_try_on/try_on.py
#   inflating: /content/virtual-try-on-outfit-change/virtual_try_on/utils.py
#    creating: /content/virtual-try-on-outfit-change/virtual_try_on_outfit_change.egg-info/
#  extracting: /content/virtual-try-on-outfit-change/virtual_try_on_outfit_change.egg-info/dependency_links.txt
#   inflating: /content/virtual-try-on-outfit-change/virtual_try_on_outfit_change.egg-info/PKG-INFO
#   inflating: /content/virtual-try-on-outfit-change/virtual_try_on_outfit_change.egg-info/requires.txt
#   inflating: /content/virtual-try-on-outfit-change/virtual_try_on_outfit_change.egg-info/SOURCES.txt
#  extracting: /content/virtual-try-on-outfit-change/virtual_try_on_outfit_change.egg-info/top_level.txt
#   inflating: /content/virtual-try-on-outfit-change/with.png
# app.py	 notebook	   setup.py  virtual_try_on
# images	 README.md	   try.png   virtual_try_on_outfit_change.egg-info
# LICENSE  requirements.txt  venv      with.png
# Added /content/virtual-try-on-outfit-change to sys.path

# %%
import os
import sys

project_path = '/content/virtual-try-on-outfit-change' # Make sure this matches your unzipped folder name

os.chdir(project_path)
print(f"Current working directory: {os.getcwd()}")

if project_path not in sys.path:
    sys.path.insert(0, project_path)
print(f"sys.path includes: {project_path in sys.path}")
# !ls
# Out:
# Current working directory: /content/virtual-try-on-outfit-change
# sys.path includes: True
# app.py	 notebook	   setup.py  virtual_try_on
# images	 README.md	   try.png   virtual_try_on_outfit_change.egg-info
# LICENSE  requirements.txt  venv      with.png

# %%
# !pip install -q transformers>=4.38.0 # Ensure a recent version for Phi-3
# !pip install -q bitsandbytes>=0.41.0
# !pip install -q accelerate>=0.25.0
# !pip install -q sentencepiece
# !pip install -r requirements.txt
# !pip install accelerate
print("Dependencies installed. You might need to restart the runtime now.")
print("Go to 'Runtime' > 'Restart session' in the Colab menu if you encounter import errors with newly installed packages.")

# %%
# !nvidia-smi

import torch

cuda_available = torch.cuda.is_available()
print(f"CUDA available: {cuda_available}")
if cuda_available:
    print(f"Device count: {torch.cuda.device_count()}")
    print(f"Current device: {torch.cuda.current_device()}")
    print(f"Device name: {torch.cuda.get_device_name(torch.cuda.current_device())}")
    print(f"PyTorch version: {torch.__version__}")
    print(f"CUDA version PyTorch was compiled with: {torch.version.cuda}")
    # Set default device to GPU
    torch.set_default_device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"PyTorch default device: {torch.get_default_device()}") # For newer PyTorch versions
else:
    print("CUDA is NOT available. Ensure you've selected a GPU runtime and PyTorch is installed correctly.")
# Out:
# Fri Jun  6 14:45:50 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# CUDA available: True
# Device count: 1
# Current device: 0
# Device name: Tesla T4
# PyTorch version: 2.6.0+cu124
# CUDA version PyTorch was compiled with: 12.4
# PyTorch default device: cuda:0

# %%
# Ensure you are in the project directory
import os
project_path = '/content/virtual-try-on-outfit-change'
if os.getcwd() != project_path:
    os.chdir(project_path)
print(f"Current working directory: {os.getcwd()}")

# Install dependencies from the MODIFIED requirements.txt
# !pip install -r requirements.txt
# !pip install accelerate # Just in case, though it's in your reqs

print("\n--- Dependencies installation complete. ---")
print("IMPORTANT: Please RESTART THE RUNTIME NOW.")
print("Go to 'Runtime' > 'Restart session' in the Colab menu.")
print("This ensures all new packages and versions are correctly loaded.")
# Out:
# Current working directory: /content/virtual-try-on-outfit-change
# Obtaining file:///content/virtual-try-on-outfit-change (from -r requirements.txt (line 9))
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: diffusers in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 1)) (0.33.1)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 2)) (1.7.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 3)) (4.52.3)
# Requirement already satisfied: insightface in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 4)) (0.7.3)
# Requirement already satisfied: onnxruntime in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 5)) (1.22.0)
# Requirement already satisfied: streamlit in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 6)) (1.45.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 7)) (2.6.0+cu124)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 8)) (11.2.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.11/dist-packages (from diffusers->-r requirements.txt (line 1)) (8.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from diffusers->-r requirements.txt (line 1)) (3.18.0)
# Requirement already satisfied: huggingface-hub>=0.27.0 in /usr/local/lib/python3.11/dist-packages (from diffusers->-r requirements.txt (line 1)) (0.32.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from diffusers->-r requirements.txt (line 1)) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from diffusers->-r requirements.txt (line 1)) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from diffusers->-r requirements.txt (line 1)) (2.32.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from diffusers->-r requirements.txt (line 1)) (0.5.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from accelerate->-r requirements.txt (line 2)) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate->-r requirements.txt (line 2)) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from accelerate->-r requirements.txt (line 2)) (6.0.2)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers->-r requirements.txt (line 3)) (0.21.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers->-r requirements.txt (line 3)) (4.67.1)
# Requirement already satisfied: onnx in /usr/local/lib/python3.11/dist-packages (from insightface->-r requirements.txt (line 4)) (1.18.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from insightface->-r requirements.txt (line 4)) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from insightface->-r requirements.txt (line 4)) (1.15.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from insightface->-r requirements.txt (line 4)) (1.6.1)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (from insightface->-r requirements.txt (line 4)) (0.25.2)
# Requirement already satisfied: easydict in /usr/local/lib/python3.11/dist-packages (from insightface->-r requirements.txt (line 4)) (1.13)
# Requirement already satisfied: cython in /usr/local/lib/python3.11/dist-packages (from insightface->-r requirements.txt (line 4)) (3.0.12)
# Requirement already satisfied: albumentations in /usr/local/lib/python3.11/dist-packages (from insightface->-r requirements.txt (line 4)) (2.0.8)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.11/dist-packages (from insightface->-r requirements.txt (line 4)) (3.16.0)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.11/dist-packages (from onnxruntime->-r requirements.txt (line 5)) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime->-r requirements.txt (line 5)) (25.2.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from onnxruntime->-r requirements.txt (line 5)) (5.29.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime->-r requirements.txt (line 5)) (1.13.1)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit->-r requirements.txt (line 6)) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from streamlit->-r requirements.txt (line 6)) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit->-r requirements.txt (line 6)) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit->-r requirements.txt (line 6)) (8.2.1)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit->-r requirements.txt (line 6)) (2.2.2)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit->-r requirements.txt (line 6)) (18.1.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit->-r requirements.txt (line 6)) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from streamlit->-r requirements.txt (line 6)) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit->-r requirements.txt (line 6)) (4.13.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.11/dist-packages (from streamlit->-r requirements.txt (line 6)) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.11/dist-packages (from streamlit->-r requirements.txt (line 6)) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.11/dist-packages (from streamlit->-r requirements.txt (line 6)) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.11/dist-packages (from streamlit->-r requirements.txt (line 6)) (6.4.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 7)) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 7)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 7)) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 7)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 7)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 7)) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 7)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 7)) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 7)) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 7)) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 7)) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 7)) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 7)) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 7)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 7)) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 7)) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 7)) (3.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime->-r requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 6)) (4.24.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 6)) (1.41.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 6)) (4.0.12)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.27.0->diffusers->-r requirements.txt (line 1)) (1.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit->-r requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit->-r requirements.txt (line 6)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit->-r requirements.txt (line 6)) (2025.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->-r requirements.txt (line 7)) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers->-r requirements.txt (line 1)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers->-r requirements.txt (line 1)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers->-r requirements.txt (line 1)) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers->-r requirements.txt (line 1)) (2025.4.26)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.11/dist-packages (from albumentations->insightface->-r requirements.txt (line 4)) (2.11.5)
# Requirement already satisfied: albucore==0.0.24 in /usr/local/lib/python3.11/dist-packages (from albumentations->insightface->-r requirements.txt (line 4)) (0.0.24)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.11/dist-packages (from albumentations->insightface->-r requirements.txt (line 4)) (4.11.0.86)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.11/dist-packages (from albucore==0.0.24->albumentations->insightface->-r requirements.txt (line 4)) (3.12.5)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.11/dist-packages (from albucore==0.0.24->albumentations->insightface->-r requirements.txt (line 4)) (6.2.1)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.11/dist-packages (from coloredlogs->onnxruntime->-r requirements.txt (line 5)) (10.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata->diffusers->-r requirements.txt (line 1)) (3.22.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->insightface->-r requirements.txt (line 4)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->insightface->-r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->insightface->-r requirements.txt (line 4)) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->insightface->-r requirements.txt (line 4)) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->insightface->-r requirements.txt (line 4)) (3.2.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prettytable->insightface->-r requirements.txt (line 4)) (0.2.13)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image->insightface->-r requirements.txt (line 4)) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image->insightface->-r requirements.txt (line 4)) (2025.5.26)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image->insightface->-r requirements.txt (line 4)) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->insightface->-r requirements.txt (line 4)) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->insightface->-r requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 6)) (5.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 6)) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 6)) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 6)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 6)) (0.25.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations->insightface->-r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations->insightface->-r requirements.txt (line 4)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations->insightface->-r requirements.txt (line 4)) (0.4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit->-r requirements.txt (line 6)) (1.17.0)
# Installing collected packages: virtual_try_on_outfit_change
#   Attempting uninstall: virtual_try_on_outfit_change
#     Found existing installation: virtual_try_on_outfit_change 0.0.1
#     Uninstalling virtual_try_on_outfit_change-0.0.1:
#       Successfully uninstalled virtual_try_on_outfit_change-0.0.1
#   Running setup.py develop for virtual_try_on_outfit_change
# Successfully installed virtual_try_on_outfit_change-0.0.1
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.7.0)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from accelerate) (6.0.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.6.0+cu124)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.32.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2025.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (4.13.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (1.1.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2025.4.26)
#
# --- Dependencies installation complete. ---
# IMPORTANT: Please RESTART THE RUNTIME NOW.
# Go to 'Runtime' > 'Restart session' in the Colab menu.
# This ensures all new packages and versions are correctly loaded.

# %%
# STEP 4: IMPORTS, INITIAL MODEL LOADING, AND MONKEY PATCH

# --- Standard and System Imports ---
import os
import sys
import torch
from PIL import Image
from IPython.display import display, Image as IPImage # For displaying PIL images in Colab
import matplotlib.pyplot as plt # For more advanced plotting if needed

# --- Ensure Project Path and Working Directory (from previous cells) ---
project_path = '/content/virtual-try-on-outfit-change' # Make sure this matches
if os.getcwd() != project_path:
    os.chdir(project_path)
if project_path not in sys.path:
    sys.path.insert(0, project_path)

print(f"Current working directory: {os.getcwd()}")
print(f"Sys.path includes project: {project_path in sys.path}")

# --- Verify GPU and PyTorch (Quick Check) ---
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    # torch.set_default_device('cuda') # Already done in your try_on.py or should be handled by .to(device)
else:
    print("WARNING: CUDA NOT AVAILABLE!")


# --- Import Your Project Modules ---
# This will trigger model downloads and loading as defined in your .py files
# Including your try_on.py (which should be configured for DPMSolverMultistepScheduler)
print("\nImporting project modules and loading models (this may take several minutes for downloads)...")
try:
    from virtual_try_on.body_segmentation import apply_segmentation, face_analyzer # Import face_analyzer for check
    from virtual_try_on.clothes_segmentation import segment_clothing
    # The following line IMPORTS YOUR try_on.py.
    # Ensure try_on.py is saved with the DPMSolverMultistepScheduler changes.
    from virtual_try_on.try_on import virtual_try_on, pipeline as sdxl_pipeline, ip_adapter_loaded_successfully

    print("\n--- All project modules imported. ---")
    print("--- Model loading messages from your .py files should have appeared above. ---")

    if 'sdxl_pipeline' in locals() and sdxl_pipeline is not None:
        print(f"SDXL Inpainting pipeline device: {sdxl_pipeline.device}")
        print(f"SDXL Pipeline using scheduler: {type(sdxl_pipeline.scheduler).__name__}") # IMPORTANT: Check which scheduler is actually loaded
    else:
        print("Warning: sdxl_pipeline not found or is None after import.")

    print(f"IP Adapter loaded successfully flag from try_on.py: {ip_adapter_loaded_successfully if 'ip_adapter_loaded_successfully' in locals() else 'Not Found'}")

    # Check insightface providers
    if 'face_analyzer' in locals() and hasattr(face_analyzer, 'providers'):
         print(f"InsightFace FaceAnalysis providers: {face_analyzer.providers}")

except ImportError as e:
    print(f"ImportError during project module import: {e}")
    print("Ensure you have restarted the runtime after installing dependencies and modifying .py files.")
    print("And that 'pip install -e .' (from requirements.txt) ran successfully.")
except Exception as e:
    print(f"An error occurred during project module import or initial model loading: {e}")
    import traceback
    traceback.print_exc()

# --- MONKEY PATCH ATTEMPT for EulerDiscreteScheduler ---
# This is added AFTER your project modules are imported, so EulerDiscreteScheduler class is known.
print("\nAttempting to monkey-patch EulerDiscreteScheduler.set_timesteps...")
try:
    from diffusers.schedulers.scheduling_euler_discrete import EulerDiscreteScheduler
    import numpy # Renamed to avoid conflict if np was already aliased
    # import torch # Already imported

    original_euler_set_timesteps = EulerDiscreteScheduler.set_timesteps

    def safe_euler_set_timesteps_wrapper(self_scheduler, num_inf_steps, dev=None, **kws):
        # print(f"MONKEY_PATCH: EulerDiscreteScheduler.set_timesteps called for device: {dev}")

        acp_on_cpu_for_numpy = False
        original_acp_device = None

        if hasattr(self_scheduler, 'alphas_cumprod'):
            if self_scheduler.alphas_cumprod.device.type == 'cuda':
                # print("MONKEY_PATCH: Euler's alphas_cumprod is on CUDA. Temporarily moving to CPU for np.array().")
                original_acp_device = self_scheduler.alphas_cumprod.device
                self_scheduler.alphas_cumprod = self_scheduler.alphas_cumprod.cpu()
                acp_on_cpu_for_numpy = True

        # Call the original method
        result = original_euler_set_timesteps(self_scheduler, num_inf_steps, dev, **kws)

        # Restore alphas_cumprod to original device if it was moved
        if acp_on_cpu_for_numpy and original_acp_device is not None:
            # print(f"MONKEY_PATCH: Restoring Euler's alphas_cumprod to {original_acp_device}.")
            self_scheduler.alphas_cumprod = self_scheduler.alphas_cumprod.to(original_acp_device)

        # Ensure resulting sigmas and timesteps are on the target device `dev`
        if dev is not None:
            if hasattr(self_scheduler, 'sigmas') and self_scheduler.sigmas.device != dev:
                # print(f"MONKEY_PATCH: Moving Euler's sigmas to {dev}.")
                self_scheduler.sigmas = self_scheduler.sigmas.to(dev)
            if hasattr(self_scheduler, 'timesteps') and self_scheduler.timesteps.device != dev:
                # print(f"MONKEY_PATCH: Moving Euler's timesteps to {dev}.")
                self_scheduler.timesteps = self_scheduler.timesteps.to(dev)

        # print("MONKEY_PATCH: EulerDiscreteScheduler.set_timesteps original call finished.")
        return result

    EulerDiscreteScheduler.set_timesteps = safe_euler_set_timesteps_wrapper
    print("EulerDiscreteScheduler.set_timesteps has been successfully monkey-patched.")

except Exception as e_patch:
    print(f"Failed to monkey-patch EulerDiscreteScheduler: {e_patch}")
    import traceback
    traceback.print_exc()

print("\n--- Step 4 Cell: Imports, Model Loading, and Patching Complete ---")
# Out:
# Current working directory: /content/virtual-try-on-outfit-change
# Sys.path includes project: True
# PyTorch version: 2.6.0+cu124
# CUDA available: True
# GPU: Tesla T4
#
# Importing project modules and loading models (this may take several minutes for downloads)...
# Initializing FaceAnalysis for body_segmentation (loading only detection and landmarks)...
# /usr/local/lib/python3.11/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py:121: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'
#   warnings.warn(
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /root/.insightface/models/buffalo_l/1k3d68.onnx landmark_3d_68
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /root/.insightface/models/buffalo_l/2d106det.onnx landmark_2d_106 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /root/.insightface/models/buffalo_l/det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /root/.insightface/models/buffalo_l/genderage.onnx genderage
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /root/.insightface/models/buffalo_l/w600k_r50.onnx recognition
# set det-size: (640, 640)
# FaceAnalysis (selective modules) initialized successfully.
# Initializing segmentation_model for body_segmentation (mattmdjaga/segformer_b2_clothes)...
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# Device set to use cuda:0
# Segmentation_model_body initialized successfully.
# Initializing segmentation_model_clothes for clothes_segmentation (mattmdjaga/segformer_b2_clothes)...
# Device set to use cuda:0
# Segmentation_model_clothes initialized successfully.
# try_on.py: CUDA is available (Tesla T4). Using GPU.
# try_on.py: Loading VAE (madebyollin/sdxl-vae-fp16-fix) with dtype: torch.float16
# try_on.py: VAE loaded successfully.
# try_on.py: Configuring DPMSolverMultistepScheduler...
# Fetching 18 files:   0%|          | 0/18 [00:00<?, ?it/s]
# vae/diffusion_pytorch_model.fp16.safeten(…):   0%|          | 0.00/167M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/659 [00:00<?, ?B/s]
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# The config attributes {'decay': 0.9999, 'inv_gamma': 1.0, 'min_decay': 0.0, 'optimization_step': 37000, 'power': 0.6666666666666666, 'update_after_step': 0, 'use_ema_warmup': False} were passed to UNet2DConditionModel, but are not expected and will be ignored. Please verify your config.json configuration file.
# try_on.py: Using DPMSolverMultistepScheduler: DPMSolverMultistepScheduler {
#   "_class_name": "DPMSolverMultistepScheduler",
#   "_diffusers_version": "0.33.1",
#   "algorithm_type": "sde-dpmsolver++",
#   "beta_end": 0.012,
#   "beta_schedule": "scaled_linear",
#   "beta_start": 0.00085,
#   "clip_sample": false,
#   "dynamic_thresholding_ratio": 0.995,
#   "euler_at_final": false,
#   "final_sigmas_type": "zero",
#   "flow_shift": 1.0,
#   "interpolation_type": "linear",
#   "lambda_min_clipped": -Infinity,
#   "lower_order_final": true,
#   "num_train_timesteps": 1000,
#   "prediction_type": "epsilon",
#   "rescale_betas_zero_snr": false,
#   "sample_max_value": 1.0,
#   "set_alpha_to_one": false,
#   "skip_prk_steps": true,
#   "solver_order": 2,
#   "solver_type": "midpoint",
#   "steps_offset": 1,
#   "thresholding": false,
#   "timestep_spacing": "leading",
#   "trained_betas": null,
#   "use_beta_sigmas": false,
#   "use_exponential_sigmas": false,
#   "use_flow_sigmas": false,
#   "use_karras_sigmas": true,
#   "use_lu_lambdas": false,
#   "variance_type": null
# }
#
# try_on.py: Loading Inpainting Pipeline (diffusers/stable-diffusion-xl-1.0-inpainting-0.1) with dtype: torch.float16
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# The config attributes {'decay': 0.9999, 'inv_gamma': 1.0, 'min_decay': 0.0, 'optimization_step': 37000, 'power': 0.6666666666666666, 'update_after_step': 0, 'use_ema_warmup': False} were passed to UNet2DConditionModel, but are not expected and will be ignored. Please verify your config.json configuration file.
# try_on.py: Inpainting Pipeline loaded successfully with custom DPM scheduler.
# try_on.py: Attempting to load IP Adapter (h94/IP-Adapter)...
# model.safetensors:  48%|####8     | 3.42G/7.11G [00:00<?, ?B/s]
# try_on.py: IP Adapter loaded successfully.
#
# --- All project modules imported. ---
# --- Model loading messages from your .py files should have appeared above. ---
# SDXL Inpainting pipeline device: cuda:0
# SDXL Pipeline using scheduler: DPMSolverMultistepScheduler
# IP Adapter loaded successfully flag from try_on.py: True
#
# Attempting to monkey-patch EulerDiscreteScheduler.set_timesteps...
# EulerDiscreteScheduler.set_timesteps has been successfully monkey-patched.
#
# --- Step 4 Cell: Imports, Model Loading, and Patching Complete ---

# %%
from PIL import Image
from IPython.display import display # Already imported, but good to be explicit

# --- Define paths to your uploaded images ---
# !!! IMPORTANT: Replace these filenames with the EXACT names of your uploaded files !!!
person_image_filename = "try.png"  # e.g., "my_model_photo.jpg"
clothes_image_filename = "with.png" # e.g., "red_dress.png"

# Construct the full paths
base_path = "/content/virtual-try-on-outfit-change/assets/"
person_image_path = base_path + person_image_filename
clothes_image_path = base_path + clothes_image_filename

# --- Load and Display Input Images ---
try:
    print(f"Attempting to load person image from: {person_image_path}")
    person_image_input = Image.open(person_image_path).resize((512, 512)).convert('RGB')

    print(f"Attempting to load clothes image from: {clothes_image_path}")
    clothes_image_input = Image.open(clothes_image_path).resize((512, 512)).convert('RGB')

    print("\nPerson image (resized to 512x512, RGB):")
    display(person_image_input)
    print("\nClothes image (resized to 512x512, RGB, for IP-Adapter):")
    display(clothes_image_input)

except FileNotFoundError as e:
    print(f"ERROR: File not found. {e}")
    print(f"Please ensure '{person_image_filename}' is in '{base_path}'")
    print(f"And '{clothes_image_filename}' is in '{base_path}'")
    print("Double-check the filenames and that they are in the 'assets' subfolder.")
except Exception as e:
    print(f"An error occurred while loading images: {e}")

# You can also verify the files exist using a shell command
print("\nVerifying files in assets directory:")
# !ls /content/virtual-try-on-outfit-change/assets/

# %%
# Step 6a: Test Body Segmentation (Mask for Inpainting)

# Make sure necessary imports are available if running cells non-sequentially
from virtual_try_on.body_segmentation import apply_segmentation
from IPython.display import display
import matplotlib.pyplot as plt # For more consistent display

# Ensure person_image_input is available from the previous step
if 'person_image_input' in locals():
    print("Generating body mask (region to be inpainted, face should be excluded)...")
    print("This uses the 'mattmdjaga/segformer_b2_clothes' model and 'insightface' for face exclusion.")

    # We pass a copy because apply_segmentation might modify the image if not careful (though yours seems safe)
    # include_face=False is crucial as it's used in your virtual_try_on function
    segmented_person_rgba, body_mask_for_inpainting_pil = apply_segmentation(person_image_input.copy(), include_face=False)

    print("\nBody Mask (L mode, for inpainting):")
    print("White areas = to be inpainted. Black areas = preserved (e.g., face, background).")

    # Displaying L-mode (grayscale) images
    plt.figure(figsize=(6,6))
    plt.imshow(body_mask_for_inpainting_pil, cmap='gray') # Use cmap='gray' for L-mode
    plt.title("Body Mask for Inpainting (Face Excluded)")
    plt.axis('off')
    plt.show()

    # --- Optional: Display the segmented person with alpha (RGBA) ---
    # This shows the original person image with the non-masked parts made transparent.
    # print("\nSegmented Person (RGBA - for visualization):")
    # plt.figure(figsize=(6,6))
    # plt.imshow(segmented_person_rgba)
    # plt.title("Segmented Person (Alpha Channel based on Mask)")
    # plt.axis('off')
    # plt.show()

else:
    print("Skipping body segmentation test: 'person_image_input' not found.")
    print("Please ensure you have run Step 5 (loading input images) successfully.")

# %%
# Step 6b: Test Clothes Segmentation (Visual Feedback)

# Make sure necessary imports are available
from virtual_try_on.clothes_segmentation import segment_clothing
import matplotlib.pyplot as plt # For displaying RGBA images properly

# Ensure clothes_image_input is available from Step 5
if 'clothes_image_input' in locals():
    print("Segmenting clothes (for visualization purposes)...")
    print("This also uses the 'mattmdjaga/segformer_b2_clothes' model.")

    # The input to segment_clothing should be an RGB PIL image
    # clothes_image_input is already in this format from Step 5
    seg_clothes_rgba = segment_clothing(clothes_image_input.copy())

    print("\nSegmented Clothes (RGBA - for visualization):")
    print("This shows the clothing item with the background made transparent.")

    plt.figure(figsize=(6,6))
    plt.imshow(seg_clothes_rgba) # imshow handles RGBA PIL images well
    plt.title("Segmented Clothes (with Alpha)")
    plt.axis('off')
    plt.show()

else:
    print("Skipping clothes segmentation test: 'clothes_image_input' not found.")
    print("Please ensure you have run Step 5 (loading input images) successfully.")

# %%
# Step 7: Run the Full Virtual Try-On Pipeline

# Make sure necessary imports and variables are available
from virtual_try_on.try_on import virtual_try_on, ip_adapter_loaded_successfully
from IPython.display import display
import time # To time the inference

# Ensure input images and the try_on function are available
if ('person_image_input' in locals() and
    'clothes_image_input' in locals() and
    'virtual_try_on' in globals() and
    ip_adapter_loaded_successfully): # Crucially check if IP Adapter is ready

    print("Starting full virtual_try_on process...")
    print("This will take some time (aiming for 2-5 minutes after model loading for 50 steps on T4)...")

    # Parameters from your app.py, can be tweaked here for experimentation
    prompt = "A realistic photo of a person wearing the provided clothes, high quality, good fit, photorealistic"
    negative_prompt = (
        "ugly, bad quality, bad anatomy, deformed body, deformed hands, deformed feet, "
        "deformed face, deformed clothing, bad clothing, distorted clothing, "
        "poorly fitting clothing, naked, text, watermark, signature, blur, low resolution, "
        "jpeg artifacts, compression artifacts, poorly drawn, cartoon, anime, sketch" # Added more negative terms
    )
    ip_adapter_scale = 0.7  # Controls IP-Adapter influence (0.0 to 1.0, sometimes higher)
    strength_value = 0.85   # Inpainting strength (0.0 to 1.0). Higher = more change from original.
                            # For try-on, 0.8-0.95 is common.
    num_inference_steps = 50 # Uses default from try_on.py if not specified,
                             # but we can set it explicitly.
                             # Lower (e.g., 25-30) for faster tests, higher (50-75) for quality.

    print(f"\nParameters for this run:")
    print(f"  Prompt: '{prompt}'")
    print(f"  IP Adapter Scale: {ip_adapter_scale}")
    print(f"  Inpainting Strength: {strength_value}")
    print(f"  Inference Steps: {num_inference_steps}")

    # Ensure we're using fresh copies of the images for the pipeline
    person_img_for_tryon = person_image_input.copy()
    clothing_img_for_ipadapter = clothes_image_input.copy()

    start_time = time.time()
    try:
        result_image_pil = virtual_try_on(
            img=person_img_for_tryon,
            clothing_ip_image=clothing_img_for_ipadapter, # Original clothes image for IP-Adapter
            prompt=prompt,
            negative_prompt=negative_prompt,
            ip_scale=ip_adapter_scale,
            strength=strength_value,
            steps=num_inference_steps # Pass the number of steps
        )
        end_time = time.time()
        inference_duration = end_time - start_time
        print(f"\n--- Inference complete in {inference_duration:.2f} seconds ---")

        print("\n--- Virtual Try-On Result ---")
        display(result_image_pil)

        # Save the result
        output_filename = f"try_on_result_steps{num_inference_steps}_strength{strength_value}_ipscale{ip_adapter_scale}.png"
        output_path = f"/content/virtual-try-on-outfit-change/assets/{output_filename}"
        result_image_pil.save(output_path)
        print(f"\nResult saved to: {output_path}")
        print("You can download it from the Colab file explorer under assets.")

    except Exception as e:
        print(f"\nAn error occurred during the virtual_try_on process: {e}")
        import traceback
        traceback.print_exc() # Print full traceback for debugging

elif not ip_adapter_loaded_successfully:
    print("IP Adapter did not load successfully. Skipping virtual try-on to prevent poor results or errors.")
else:
    print("Skipping virtual try-on: Ensure input images ('person_image_input', 'clothes_image_input') "
          "are loaded and the 'virtual_try_on' function is available.")

# %%
# !python /content/virtual-try-on-outfit-change/app_gradio.py
# Out:
# Project root added to sys.path: /content/virtual-try-on-outfit-change
# Importing virtual_try_on.try_on - This will load models (may take time)...
# 2025-06-05 10:37:31.856647: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749119852.009694   47650 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749119852.053565   47650 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-05 10:37:32.417876: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Initializing FaceAnalysis for body_segmentation...
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'sdpa_kernel': '0', 'use_tf32': '1', 'fuse_conv_bias': '0', 'prefer_nhwc': '0', 'tunable_op_max_tuning_duration_ms': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_tuning_enable': '0', 'tunable_op_enable': '0', 'use_ep_level_unified_stream': '0', 'device_id': '0', 'has_user_compute_stream': '0', 'gpu_external_empty_cache': '0', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_mem_limit': '18446744073709551615', 'gpu_external_alloc': '0', 'gpu_external_free': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'do_copy_in_default_stream': '1', 'enable_cuda_graph': '0', 'user_compute_stream': '0', 'cudnn_conv_use_max_workspace': '1'}}
# model ignore: /root/.insightface/models/buffalo_l/1k3d68.onnx landmark_3d_68
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'sdpa_kernel': '0', 'use_tf32': '1', 'fuse_conv_bias': '0', 'prefer_nhwc': '0', 'tunable_op_max_tuning_duration_ms': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_tuning_enable': '0', 'tunable_op_enable': '0', 'use_ep_level_unified_stream': '0', 'device_id': '0', 'has_user_compute_stream': '0', 'gpu_external_empty_cache': '0', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_mem_limit': '18446744073709551615', 'gpu_external_alloc': '0', 'gpu_external_free': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'do_copy_in_default_stream': '1', 'enable_cuda_graph': '0', 'user_compute_stream': '0', 'cudnn_conv_use_max_workspace': '1'}}
# find model: /root/.insightface/models/buffalo_l/2d106det.onnx landmark_2d_106 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'sdpa_kernel': '0', 'use_tf32': '1', 'fuse_conv_bias': '0', 'prefer_nhwc': '0', 'tunable_op_max_tuning_duration_ms': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_tuning_enable': '0', 'tunable_op_enable': '0', 'use_ep_level_unified_stream': '0', 'device_id': '0', 'has_user_compute_stream': '0', 'gpu_external_empty_cache': '0', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_mem_limit': '18446744073709551615', 'gpu_external_alloc': '0', 'gpu_external_free': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'do_copy_in_default_stream': '1', 'enable_cuda_graph': '0', 'user_compute_stream': '0', 'cudnn_conv_use_max_workspace': '1'}}
# find model: /root/.insightface/models/buffalo_l/det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'sdpa_kernel': '0', 'use_tf32': '1', 'fuse_conv_bias': '0', 'prefer_nhwc': '0', 'tunable_op_max_tuning_duration_ms': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_tuning_enable': '0', 'tunable_op_enable': '0', 'use_ep_level_unified_stream': '0', 'device_id': '0', 'has_user_compute_stream': '0', 'gpu_external_empty_cache': '0', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_mem_limit': '18446744073709551615', 'gpu_external_alloc': '0', 'gpu_external_free': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'do_copy_in_default_stream': '1', 'enable_cuda_graph': '0', 'user_compute_stream': '0', 'cudnn_conv_use_max_workspace': '1'}}
# model ignore: /root/.insightface/models/buffalo_l/genderage.onnx genderage
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'sdpa_kernel': '0', 'use_tf32': '1', 'fuse_conv_bias': '0', 'prefer_nhwc': '0', 'tunable_op_max_tuning_duration_ms': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_tuning_enable': '0', 'tunable_op_enable': '0', 'use_ep_level_unified_stream': '0', 'device_id': '0', 'has_user_compute_stream': '0', 'gpu_external_empty_cache': '0', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_mem_limit': '18446744073709551615', 'gpu_external_alloc': '0', 'gpu_external_free': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'do_copy_in_default_stream': '1', 'enable_cuda_graph': '0', 'user_compute_stream': '0', 'cudnn_conv_use_max_workspace': '1'}}
# model ignore: /root/.insightface/models/buffalo_l/w600k_r50.onnx recognition
# set det-size: (640, 640)
# FaceAnalysis initialized.
# Initializing segmentation_model for body_segmentation...
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# Device set to use cuda:0
# Segmentation_model initialized.
# CUDA is available. Using GPU.
# Loading VAE with dtype: torch.float16
# VAE loaded successfully.
# Loading Inpainting Pipeline with dtype: torch.float16 and variant: fp16
# Loading pipeline components...:  71% 5/7 [00:12<00:07,  3.66s/it]The config attributes {'decay': 0.9999, 'inv_gamma': 1.0, 'min_decay': 0.0, 'optimization_step': 37000, 'power': 0.6666666666666666, 'update_after_step': 0, 'use_ema_warmup': False} were passed to UNet2DConditionModel, but are not expected and will be ignored. Please verify your config.json configuration file.
# Loading pipeline components...: 100% 7/7 [01:02<00:00,  8.95s/it]
# Using DPMSolverMultistepScheduler: DPMSolverMultistepScheduler {
#   "_class_name": "DPMSolverMultistepScheduler",
#   "_diffusers_version": "0.33.1",
#   "algorithm_type": "sde-dpmsolver++",
#   "beta_end": 0.012,
#   "beta_schedule": "scaled_linear",
#   "beta_start": 0.00085,
#   "clip_sample": false,
#   "dynamic_thresholding_ratio": 0.995,
#   "euler_at_final": false,
#   "final_sigmas_type": "zero",
#   "flow_shift": 1.0,
#   "interpolation_type": "linear",
#   "lambda_min_clipped": -Infinity,
#   "lower_order_final": true,
#   "num_train_timesteps": 1000,
#   "prediction_type": "epsilon",
#   "rescale_betas_zero_snr": false,
#   "sample_max_value": 1.0,
#   "set_alpha_to_one": false,
#   "skip_prk_steps": true,
#   "solver_order": 2,
#   "solver_type": "midpoint",
#   "steps_offset": 1,
#   "thresholding": false,
#   "timestep_spacing": "leading",
#   "trained_betas": null,
#   "use_beta_sigmas": false,
#   "use_exponential_sigmas": false,
#   "use_flow_sigmas": false,
#   "use_karras_sigmas": true,
#   "use_lu_lambdas": false,
#   "variance_type": null
# }
#
# Loading pipeline components...:  71% 5/7 [00:01<00:00,  2.85it/s]The config attributes {'decay': 0.9999, 'inv_gamma': 1.0, 'min_decay': 0.0, 'optimization_step': 37000, 'power': 0.6666666666666666, 'update_after_step': 0, 'use_ema_warmup': False} were passed to UNet2DConditionModel, but are not expected and will be ignored. Please verify your config.json configuration file.
# Loading pipeline components...: 100% 7/7 [00:05<00:00,  1.26it/s]
# Inpainting Pipeline loaded successfully with custom DPM scheduler.
# Attempting to load IP Adapter...
# IP Adapter loaded successfully.
# Models loaded/checked by try_on.py import in 151.11 seconds.
# Try-on will run on device: cuda
# Defining Gradio interface...
# Models should have been loaded during import of try_on.py.
# Launching Gradio demo...
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://15061787bd0aa16d3d.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
#
# --- Gradio: New Try-On Request ---
# Person image type: <class 'PIL.Image.Image'>, Clothes image type: <class 'PIL.Image.Image'>
# Prompt: 'A realistic photo of a person wearing the provided clothes, high quality, good fit, photorealistic'
# IP Scale: 0.7, Strength: 0.85, Steps: 50
# Images resized to (512, 512)
# Using 50 inference steps on cuda with DPM scheduler.
# Applying body segmentation for mask...
# Starting virtual try-on inference...
# Using IP Adapter with scale: 0.7
# Inference complete.
# Gradio: Inference completed in 43.15 seconds.
#
# --- Gradio: New Try-On Request ---
# Person image type: <class 'PIL.Image.Image'>, Clothes image type: <class 'PIL.Image.Image'>
# Prompt: 'A realistic photo of a person wearing the provided clothes, high quality, good fit, photorealistic'
# IP Scale: 0.7, Strength: 0.85, Steps: 50
# Images resized to (512, 512)
# Using 50 inference steps on cuda with DPM scheduler.
# Applying body segmentation for mask...
# Starting virtual try-on inference...
# Using IP Adapter with scale: 0.7
# Inference complete.
# Gradio: Inference completed in 43.00 seconds.
#
# --- Gradio: New Try-On Request ---
# Person image type: <class 'PIL.Image.Image'>, Clothes image type: <class 'PIL.Image.Image'>
# Prompt: 'A realistic photo of a person wearing the provided clothes, high quality, good fit, photorealistic'
# IP Scale: 0.7, Strength: 0.85, Steps: 50
# Images resized to (512, 512)
# Using 50 inference steps on cuda with DPM scheduler.
# Applying body segmentation for mask...
# Starting virtual try-on inference...
# Using IP Adapter with scale: 0.7
# Inference complete.
# Gradio: Inference completed in 41.94 seconds.
#
# --- Gradio: New Try-On Request ---
# Person image type: <class 'PIL.Image.Image'>, Clothes image type: <class 'PIL.Image.Image'>
# Prompt: 'A realistic photo of a person wearing the provided clothes, high quality, good fit, photorealistic'
# IP Scale: 0.7, Strength: 0.85, Steps: 50
# Images resized to (512, 512)
# Using 50 inference steps on cuda with DPM scheduler.
# Applying body segmentation for mask...
# Starting virtual try-on inference...
# Using IP Adapter with scale: 0.7
# Inference complete.
# Gradio: Inference completed in 42.06 seconds.
#
# --- Gradio: New Try-On Request ---
# Person image type: <class 'PIL.Image.Image'>, Clothes image type: <class 'PIL.Image.Image'>
# Prompt: 'A realistic photo of a person wearing the provided clothes, high quality, good fit, photorealistic'
# IP Scale: 0.7, Strength: 0.85, Steps: 50
# Images resized to (512, 512)
# Using 50 inference steps on cuda with DPM scheduler.
# Applying body segmentation for mask...
# Starting virtual try-on inference...
# Using IP Adapter with scale: 0.7
# Inference complete.
# Gradio: Inference completed in 41.82 seconds.
